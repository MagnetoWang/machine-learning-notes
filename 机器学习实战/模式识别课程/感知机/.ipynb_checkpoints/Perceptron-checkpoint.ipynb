# %% [markdown]
# # 简单感知机示例

# %% [markdown]
# ## 参考资料
# ### https://maviccprp.github.io/a-perceptron-in-just-a-few-lines-of-python-code/

# %%
import numpy as np

X = np.array([
    [-2,4,-1],
    [4,1,-1],
    [1, 6, -1],
    [2, 4, -1],
    [6, 2, -1],

])

y = np.array([-1,-1,1,1,1])

def perceptron_sgd(X, Y):
    w = np.zeros(len(X[0]))
    eta = 1
    epochs = 20

    for t in range(epochs):
        for i, x in enumerate(X):
            if (np.dot(X[i], w)*Y[i]) <= 0:
                w = w + eta*X[i]*Y[i]

    return w

w = perceptron_sgd(X,y)
print(w)
# Out:
# [ 2.  3. 13.]

# %%
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
X = np.array([
    [-2,4,-1],
    [4,1,-1],
    [1, 6, -1],
    [2, 4, -1],
    [6, 2, -1],

])
y = np.array([-1,-1,1,1,1])
for d, sample in enumerate(X):
    # Plot the negative samples
    if d < 2:
        plt.scatter(sample[0], sample[1], s=120, marker='_', linewidths=2)
    # Plot the positive samples
    else:
        plt.scatter(sample[0], sample[1], s=120, marker='+', linewidths=2)

# Print a possible hyperplane, that is seperating the two classes.
plt.plot([-2,6],[6,0.5])

# %%
def perceptron_sgd(X, Y):
    w = np.zeros(len(X[0]))
    eta = 1
    epochs = 10

    for epoch in range(epochs):
        for i, x in enumerate(X):
            if (np.dot(X[i], w)*Y[i]) <= 0:
                w = w + eta*X[i]*Y[i]
    return w

def perceptron_sgd_plot(X, Y):
    '''
    train perceptron and plot the total loss in each epoch.
    
    :param X: data samples
    :param Y: data labels
    :return: weight vector as a numpy array
    '''
    w = np.zeros(len(X[0]))
    eta = 1
    n = 30
    errors = []

    for t in range(n):
        total_error = 0
        for i, x in enumerate(X):
            if (np.dot(X[i], w)*Y[i]) <= 0:
                total_error += (np.dot(X[i], w)*Y[i])
                w = w + eta*X[i]*Y[i]
        errors.append(total_error*-1)
        
    plt.plot(errors)
    plt.xlabel('Epoch')
    plt.ylabel('Total Loss')
    
    return w


print(perceptron_sgd_plot(X,y))
# Out:
# [ 2.  3. 13.]

# %% [markdown]
# Get the current Axes instance on the current figure matching the given keyword args, or create one.

# %%
for d, sample in enumerate(X):
    # Plot the negative samples
    if d < 2:
        plt.scatter(sample[0], sample[1], s=120, marker='_', linewidths=2)
    # Plot the positive samples
    else:
        plt.scatter(sample[0], sample[1], s=120, marker='+', linewidths=2)

# Add our test samples

plt.scatter(2,2, s=120, marker='_', linewidths=2, color='yellow')
plt.scatter(4,3, s=120, marker='+', linewidths=2, color='blue')

# Print the hyperplane calculated by perceptron_sgd()
x2=[w[0],w[1],-w[1],w[0]]
x3=[w[0],w[1],w[1],-w[0]]

x2x3 =np.array([x2,x3])
X,Y,U,V = zip(*x2x3)
ax = plt.gca()
ax.quiver(X,Y,U,V,scale=1, color='blue')

# %% [markdown]
# # 感知机算法细节补充
# ## https://en.wikipedia.org/wiki/Gradient_descent
# ## http://www.wikiwand.com/en/Perceptron

# %%
# From calculation, it is expected that the local minimum occurs at x=9/4
#The gradient descent algorithm is applied to find a local minimum of the function f(x)=x4−3x3+2, with derivative f'(x)=4x3−9x2. Here is an implementation in the Python programming language.
import numpy as np
import matplotlib.pyplot as plt

cur_x = 2.2 # The algorithm starts at x=6
gamma = 0.01 # step size multiplier
precision = 0.00001
previous_step_size = 1/precision # some large value

df = lambda x: 4 * x**3 - 9 * x**2
f= lambda x: pow(x,4)-3*pow(x,3)+2


while previous_step_size > precision:
    plt.scatter(cur_x,f(cur_x),c='r', marker = 'o', s=10)
    prev_x = cur_x
    cur_x += -gamma * df(prev_x)
    previous_step_size = abs(cur_x - prev_x)
    
plt.show()
print("The local minimum occurs at", cur_x)
#The output for the above will be: ('The local minimum occurs at', 2.2499646074278457)
# Out:
# The local minimum occurs at 2.249962075705348

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#
# 矩阵中添加行：
#
# numpy.row_stack(mat, a)
#
# 矩阵中添加列：
#
# numpy.column_stack(mat,a)

# %%
import numpy as np
import matplotlib.pyplot as plt


'''

生成符合题目要求的数据集，并画出数据点的位置

'''
def plot_data(data1,data2):
    #data_set=np.array([])
   # print(data_set)
    print(np.array([data1[0][1],data1[1][1],data1[0][1]+data1[1][1]]))
    print([data1[0][1],data1[1][1],data1[0][1]+data1[1][1]])
    for i in range(50):
        if(data1[0][i]+data1[1][i]>=1):
            plt.scatter(data1[0][i],data1[1][i],c='r')
            if(i==0):
                data_set=np.array([data1[0][i],data1[1][i],data1[0][i]+data1[1][i]])
            else:
                a=np.array([data1[0][i],data1[1][i],data1[0][i]+data1[1][i]])
                data_set=np.row_stack((data_set,a))
            
            
            
    

    for i in range(50):
        if(data2[0][i]+data2[1][i]<1):
            plt.scatter(data2[0][i],data2[1][i],c='g')
            
            
           
            a=np.array([data2[0][i],data2[1][i],data2[0][i]+data2[1][i]])
            data_set=np.row_stack((data_set,a))
            
            
    #print(" data_set  " )
    #print(data_set)

    plt.show()
    return data_set







loc,scale=1,0.2 #均值与标准差
#loc=0.0, scale=1.0, size=None
range_number=50
data1=np.array([np.random.normal(loc,scale,range_number),np.random.normal(loc,scale,range_number)])
loc,scale=0,0.2
data2=np.array([np.random.normal(loc,scale,range_number),np.random.normal(loc,scale,range_number)])
print(data1.shape)
print(data2)
#data_set=plot_data(data1,data2)


def Learning_algorithm(data_set):
    w=np.array([0,0])
    b=1
    print(data_set.shape)
    for row in data_set:
        print(row)
        label=row[2]
        data=np.array(row[0],row[1])
        if(np.dow(w,data)-label>0):
            w=np.dot (w,data)-label
        else:
            w=np.dot (w,data)-label


data_set=plot_data(data1,data2)
#print(data_set)
Learning_algorithm(data_set)
# Out:
# (2, 50)
# [[ 0.20682034 -0.09358827 -0.01655195  0.02456404  0.16286646  0.09491782
#   -0.1234094  -0.28795714  0.15697061  0.06184296 -0.12745489  0.25525404
#   -0.39292845 -0.07555571 -0.35940723 -0.02965431 -0.3893004   0.01431904
#   -0.03024621  0.22705327  0.17281185  0.14060263 -0.15464113  0.33742181
#   -0.17412734  0.03066812 -0.02133156 -0.03817571  0.26521054 -0.06274791
#    0.12201083 -0.11602261 -0.1364126   0.0160341   0.08662829 -0.21647028
#    0.01527251  0.26211139  0.23139746  0.00248621  0.34407253  0.03531211
#   -0.4419824   0.26997443 -0.28560215 -0.26504888 -0.16936996 -0.03493324
#   -0.46288294 -0.0824742 ]
#  [ 0.0782487  -0.16014322 -0.17598957 -0.29653399 -0.15207638  0.46008053
#    0.01388038 -0.20660655 -0.14260658 -0.02561626 -0.15081601  0.24487637
#   -0.30721908 -0.07755316 -0.22879461  0.00634048  0.17145172  0.06649698
#   -0.20592568  0.22247829  0.02902344 -0.20382882 -0.11722841 -0.09599373
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt


'''

生成符合题目要求的数据集，并画出数据点的位置

'''
def plot_data(data1,data2):
    #data_set=np.array([])
   # print(data_set)
    print(np.array([data1[0][1],data1[1][1],data1[0][1]+data1[1][1]]))
    print([data1[0][1],data1[1][1],data1[0][1]+data1[1][1]])
    for i in range(50):
        if(data1[0][i]+data1[1][i]>=1):
            plt.scatter(data1[0][i],data1[1][i],c='r')
            if(i==0):
                data_set=np.array([data1[0][i],data1[1][i],data1[0][i]+data1[1][i]])
            else:
                a=np.array([data1[0][i],data1[1][i],data1[0][i]+data1[1][i]])
                data_set=np.row_stack((data_set,a))
            
            
            
    

    for i in range(50):
        if(data2[0][i]+data2[1][i]<1):
            plt.scatter(data2[0][i],data2[1][i],c='g')
            
            
           
            a=np.array([data2[0][i],data2[1][i],data2[0][i]+data2[1][i]])
            data_set=np.row_stack((data_set,a))
            
            
    #print(" data_set  " )
    #print(data_set)

    plt.show()
    return data_set


def Learning_algorithm(data_set):
    #基本量的初始化。
    step=1
    w=np.array([0,0])
    b=1
    #转置
    #data_set=data_set.T
    print(data_set.shape)
    for row in data_set:
        #print(row.shape)
        #print(row)
        label=row[ 2]
        #print("label")
        #print("label = "+str(label))
        data=np.array(row[0],row[1])
        #print("np.dot(w,data) = "+str(np.dot(w,data)))
        #print("w " + str(w))
        #感知机的核心算法。到底如何迭代，如何计算。只有懂这个才算真正明白感知机的计算过程
        if(sum(np.dot(w,data))-label>0):
            #w=w-np.dot (w,data)*label
            w=w-data*label*step
        else:
            w=w+data*label*step
            
    return w
            
        




loc,scale=1,0.2 #均值与标准差
#loc=0.0, scale=1.0, size=None
range_number=50
data1=np.array([np.random.normal(loc,scale,range_number),np.random.normal(loc,scale,range_number)])
loc,scale=0,0.2
data2=np.array([np.random.normal(loc,scale,range_number),np.random.normal(loc,scale,range_number)])
print(data1.shape)
print(data2)
#data_set=plot_data(data1,data2)





data_set=plot_data(data1,data2)
#print(data_set)
w=Learning_algorithm(data_set)
g=w[0]*x1+w[1]*x2+1
# Out:
# (2, 50)
# [[ 0.18091443  0.04463475  0.12172925  0.32598406 -0.00803178  0.23399155
#   -0.37148282 -0.23185639 -0.10856579 -0.30622501  0.27692776 -0.02520867
#   -0.18372084 -0.15442542  0.08843597 -0.06281451  0.16936219 -0.08945491
#   -0.0750611   0.26494615 -0.04273817  0.20136782 -0.25436479  0.04289995
#   -0.14284004 -0.12064897 -0.30082066 -0.30912914 -0.05753515  0.19257362
#    0.24563647 -0.06653362 -0.11363643 -0.10579365  0.04152135  0.05694197
#   -0.06294232  0.00471607  0.10897527 -0.01230119 -0.0892452  -0.18806409
#    0.36182881 -0.5423667   0.11038744  0.25242174 -0.20201683  0.51789658
#   -0.10679501 -0.01734435]
#  [ 0.28388597 -0.24886984  0.18491248 -0.16038087 -0.0112034  -0.0431505
#    0.21100972  0.01429224  0.12537534 -0.38201787 -0.3602136  -0.19085409
#   -0.12514126  0.00649292  0.23086255  0.05751418  0.25470743 -0.0220449
#    0.40812129  0.0549709  -0.25171237 -0.07906734 -0.08078596  0.00974076
# ...

# %%
# Out:
# [0.93340862 0.93942147 1.87283009]
# [0.9334086205431886, 0.9394214682757347, 1.8728300888189233]
# None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-d895ba7655b7> in <module>()
#      15 data_set=plot_data(data1,data2)
#      16 print(data_set)
# ---> 17 Learning_algorithm(data_set)
#
# <ipython-input-82-d895ba7655b7> in Learning_algorithm(data_set)
#       2     w=np.array([0,0])
#       3     b=1
# ----> 4     print(data_set.shape())
#       5     for row in data_set:
#       6         print(row)
#
# AttributeError: 'NoneType' object has no attribute 'shape'
